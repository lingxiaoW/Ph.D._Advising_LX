# %% [markdown]
# ### Libraries

# %%
from rdkit import Chem
from rdkit.Chem.rdMolDescriptors import CalcMolFormula
from rdkit.Chem import Draw
from rdkit import DataStructs
from rdkit.Chem import AllChem

# %% [markdown]
# ### autoDGEBA271-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1cc(C)c(cc1(CC))C(C)(C)c1cc(C)c(cc1(CC))OCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoDGEBA326-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(c(C)c1(CC))C(C)(C)c1ccc(c(C)c1(CC))OCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_409-APA

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1cc2ccc(cc2cc1)c1ccc(cc1)C#Cc2ccc(cc2)C1CC2CC(CC2C1)OCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C1=CC(=CC=C1C2=CC=C(C=C2)N)N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_545-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(cc1)c2ccc(cc2)c1ccc(cc1)C#Cc2ccc(cc2)C1CC2CC(CC2C1)OCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_590-APA

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(cc1)C#Cc2ccc(cc2)C(=O)CCOCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C1=CC(=CC=C1C2=CC=C(C=C2)N)N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_590-Autohardener40

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(cc1)C#Cc2ccc(cc2)C(=O)CCOCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C(N)1=C(N)C=C(C=C1)C#CC1=CC=CC=C1")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_590-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(cc1)C#Cc2ccc(cc2)C(=O)CCOCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2_592-APA

# %%
mol_Epoxy = Chem.MolFromSmiles("O2CC2COc1ccc(cc1)C#Cc2ccc(cc2)C(=O)CCOCC2CO2")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C1=CC(=CC=C1C2=CC=C(C=C2)N)N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2256-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("Cc5cc(OCC1CO1)cc6ccc(C(=O)c4ccc3cc(OCC2CO2)cc(C)c3c4)cc56")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2302-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("Cc5cc4cc(C(=O)c3cc2ccc(OCC1CO1)cc2cc3C)ccc4cc5OCC6CO6")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2348-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("Cc5c(OCC1CO1)ccc6cc(C(=O)c4ccc3cc(OCC2CO2)ccc3c4C)ccc56")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy2394-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("Cc5cc(OCC1CO1)cc6ccc(C(=O)c4cc(C)c3cc(OCC2CO2)ccc3c4)cc56")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy3038-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("CCc5c(OCC1CO1)ccc6cc(C(=O)c4ccc3cc(OCC2CO2)ccc3c4CC)ccc56")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### autoEpoxy3084-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("CCc5cc(OCC1CO1)cc6ccc(C(=O)c4ccc3cc(OCC2CO2)cc(CC)c3c4)cc56")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-Autohardener40

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C(N)1=C(N)C=C(C=C1)C#CC1=CC=CC=C1")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-Autohardener70

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("C(N)OC(=O)C1=CC=CC(N)=C1C(=O)OC")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-Autohardener96

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("O=C(C1=CC=CC(N)=C1)C1=CC(N)=CC=C1")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-Autohardener142

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("O=S(=O)(C1=C(N)C=CC=C1)C1=CC=C(N)C=C1")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-dDAP_Base134

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("NCC(=O)C(COC)N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-dMPDA_Base117

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("COCc1c(N)ccc(C)c1N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-dMPDA_Base227

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("c1c(C)cc(N)c(COC)c1(N)")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBA-MPDA_Base4

# %%
mol_Epoxy = Chem.MolFromSmiles("CC(C)(C1=CC=C(C=C1)OCC2CO2)C3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("Cc1c(N)cccc1N")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# ### DGEBF-IPD

# %%
mol_Epoxy = Chem.MolFromSmiles("C1C(O1)COC2=CC=C(C=C2)CC3=CC=C(C=C3)OCC4CO4")
img = Draw.MolToImage(mol_Epoxy)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
mol_Hardener = Chem.MolFromSmiles("CC1(CC(CC(C1)(C)CN)N)C")
img = Draw.MolToImage(mol_Hardener)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
